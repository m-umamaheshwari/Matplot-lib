# %% [markdown]
# <a href="https://colab.research.google.com/github/m-umamaheshwari/Matplot-lib/blob/main/matplot_pie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
y=np.array([35,25,25,15])
import matplotlib.pyplot as plt
plt.pie(y)
plt.show()
