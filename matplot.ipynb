# %% [markdown]
# <a href="https://colab.research.google.com/github/m-umamaheshwari/Matplot-lib/blob/main/matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
xpts=np.array([0,6])
ypts=np.array([0,100])
plt.plot(xpts,ypts)
plt.show()
